# %%
import pandas as pd

# dando entrada nas tabelas que serão usadas
produtos_df = pd.read_csv(r'E:\Programas\Projetos-Python\Pandas\Contoso - Cadastro Produtos.csv', sep=';')
clientes_df = pd.read_csv(r'E:\Programas\Projetos-Python\Pandas\Contoso - Clientes.csv', sep=';')
lojas_df = pd.read_csv(r'E:\Programas\Projetos-Python\Pandas\Contoso - Lojas.csv', sep=';')
vendas2017_df = pd.read_csv(r'E:\Programas\Projetos-Python\Pandas\Contoso - Vendas  - 2017.csv', sep=';')

# filtrando as tabelas conforme as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome da Marca']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

# mesclando e renomeando colunas
vendas2017_df = vendas2017_df.merge(produtos_df, on='ID Produto')
vendas2017_df = vendas2017_df.merge(clientes_df, on='ID Cliente')
vendas2017_df = vendas2017_df.merge(lojas_df, on='ID Loja').rename(columns={'E-mail' : 'E-mail do Cliente'})
display(vendas2017_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                640549    28/08/2017    01/09/2017         4       86
# 2                102415    12/02/2017    13/02/2017         1       86
# 3                940800    16/12/2017    22/12/2017         6       86
# 4                715385    28/09/2017    28/09/2017         0       86
# ...                 ...           ...           ...       ...      ...
# 980637           766546    14/10/2017    14/10/2017         0       65
# 980638           540137    19/07/2017    20/07/2017         1       65
# 980639           864227    17/11/2017    17/11/2017         0       65
# 980640           553823    24/07/2017    25/07/2017         1       65
# 980641           508546    06/07/2017    10/07/2017         4       65
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# Transformar a coluna de data da venda em colunas diferentes para mês, dia e ano
#     - pd.to_datetima(argumento, format='formato que vc deseja') - argumento é o que vc deseja passar para formato de data, por exemplo a coluna no exercício abaixo
#     - vendas2017_df['argumento'] - Se não existir uma coluna com esse índice, ele ira criar uma coluna
#     - .dt.argumento - usar day, month ou year como argumento visando o dado desejado

# %%
# transformando a coluna data da venda do formato objeto para uma data
vendas2017_df['Data da Venda'] = pd.to_datetime(vendas2017_df['Data da Venda'], format='%d/%m/%Y') # colocar o mesmo formato utilizado na base(no caso, utilizado na coluna em questão)
#display(vendas2017_df['Data da Venda'])

# criando colunas para o dia, mês e ano
vendas2017_df['Dia da Venda'] = vendas2017_df['Data da Venda'].dt.day
vendas2017_df['Mes da Venda'] = vendas2017_df['Data da Venda'].dt.month
vendas2017_df['Ano da Venda'] = vendas2017_df['Data da Venda'].dt.year
display(vendas2017_df)

# removendo a coluna data da venda
vendas2017_df = vendas2017_df.drop(['Data da Venda'], axis=1)
display(vendas2017_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    2017-01-01    02/01/2017         1       86
# 1                640549    2017-08-28    01/09/2017         4       86
# 2                102415    2017-02-12    13/02/2017         1       86
# 3                940800    2017-12-16    22/12/2017         6       86
# 4                715385    2017-09-28    28/09/2017         0       86
# ...                 ...           ...           ...       ...      ...
# 980637           766546    2017-10-14    14/10/2017         0       65
# 980638           540137    2017-07-19    20/07/2017         1       65
# 980639           864227    2017-11-17    17/11/2017         0       65
# 980640           553823    2017-07-24    25/07/2017         1       65
# 980641           508546    2017-07-06    10/07/2017         4       65
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
